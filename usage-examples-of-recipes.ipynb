# %%
# %run ../input/python-recipes/dhtml.py
dhtml('HTML Files Embedding','#aa33ff',f2,fs8)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#aa33ff; font-size:30px;'>
#     HTML Files Embedding</h1>

# %%
import os
file_path='../input/html-recipes/'
os.listdir(file_path)
# Out:
# ['circle_mouse.html',
#  'rotated_graph_path.html',
#  '3dline_graph.html',
#  'interactive_polar_plotting.html',
#  'font_line.html',
#  'set_operation.html',
#  'table_structure.html',
#  'font_color.html',
#  'interactive_tachyon_projection.html',
#  'butterfly_function.html',
#  'zoom_function.html',
#  'glinechart.html',
#  'canvas_draw.html',
#  'highcharts_polygon.html',
#  'external_json.html',
#  'world_map.html',
#  'code_input.html',
#  'color_interpolation.html',
#  'function_3dplotting.html',
#  'rpackages.html',
#  'interactive_tachyon_plotting.html',
#  'smc_rotated_polygon.html',
#  'interactive_graph.html',
#  'interactive_3dplotting.html',
#  'curve_evolute.html',
#  'graph.html',
#  'sklearn_clusters.html',
#  'highcharts_euromap.html',
#  'zoom_effect.html',
#  'html_recipes_id.csv',
#  'animated_button.html',
#  'uri_encode.html']

# %%
file1='animated_button.html'
with open(file_path+file1,'rb')as inputf:
    with open(file1,'wb')as outputf:
        outputf.write(inputf.read())
        outputf.close()
    inputf.close()
HTML('''<div id='data'><iframe src="'''+file1+\
     ''' " height="100" width="400"></iframe></div>''')
# Out:
# <div id='data'><iframe src="animated_button.html " height="100" width="400"></iframe></div>

# %%
# %run ../input/python-recipes/embedding_html_string.py
file1='circle_mouse.html'
with open(file_path+file1,'r') as f:
    html_string=f.read()
    f.close()
embedding_html_string(html_string,520,520,1)
# Out:
# <div id="html_string1"><iframe src="file1.html" height=520 width=520></iframe></div>

# %%
file2='interactive_tachyon_projection.html'
from IPython.display import HTML
with open(file_path+file2,'r') as f:
    html_str=f.read()
    f.close()
HTML(html_str)
# Out:
# <html>
#   <head>
#     <meta charset='utf-8'>
#     <meta name='viewport' content='width=device-width'>
#     <script src='https://sagecell.sagemath.org/static/embedded_sagecell.js'></script>
#     <script>$(function(){
#       sagecell.makeSagecell({
#         inputLocation:'#cell013',template:sagecell.templates.minimal,
#         evalButtonText:'run'}); });
#     </script>
#   </head>
#   <style>
#   h3 {color:#aa33ff; text-shadow:4px 4px 4px slategray;}
#   pre {width:99%; padding-left:3px; border:2px double slategray; }
#   .sagecell_output {width:99%; border:2px double slategray; padding-right:1px;}
#   .sagecell_interactControlLabel:hover {padding-left:3px; color:#aa33ff; font-size:120%;}
#   .sagecell_interactOutput {padding-left:3px;}
#   </style>
#   <body>
# <h3>$$\large{\mathbb{Interactive \; Tachyon \; Projections}}$$</h3>
# <p>Click the $\large{\mathbb{run}}$ button to display an example.</p>
# <pre><code>
# @interact
# def _(projection=selector(
#           ['perspective','fisheye','perspective_dof']),
#       cmap=selector(
#           ['hsv','jet','cool','hot','prism','ocean'])):
#     k=1; e=[[[k,-k,k],[0,0,0]],[[0,0,0],[k,k,k]],
#             [[k,k,k],[-k,k,k]],[[-k,k,k],[-k,-k,k]],
#             [[-k,-k,k],[k,-k,k]],[[k,-k,k],[k,k,k]],
#             [[k,k,k],[k,k,-k]],[[k,k,-k],[-k,k,-k]],
#             [[-k,k,-k],[-k,-k,-k]],[[-k,-k,-k],[k,-k,-k]],
#             [[k,-k,-k],[k,k,-k]],[[k,k,-k],[0,0,0]],
#             [[0,0,0],[k,-k,-k]],[[k,-k,-k],[k,-k,k]]]
#     if projection=='perspective_dof':
#         t=Tachyon(xres=400,yres=400,projection=projection,
#                   camera_center=(-3.5,0.,0.),
#                   antialiasing=3,raydepth=5,
#                   focallength='2.0',aperture='.003')
#     else: t=Tachyon(xres=400,yres=400,projection=projection,
#                     camera_center=(-3.5,0.,0.))
#     for i in [0..13]:
#         t.texture('t%s'%str(i),opacity=.3,
#                   color=colormaps[cmap](.077*i)[:3])
#         t.fcylinder(e[i][0],e[i][1],.06,'t%s'%str(i))
#     t.light((-5,-5,5),.1,(1,1,1)); t.show()
#
# </code></pre><br/>
# <div id='cell013'><script type='text/x-sage'>
# @interact
# def _(projection=selector(
#           ['perspective','fisheye','perspective_dof']),
#       cmap=selector(
#           ['hsv','jet','cool','hot','prism','ocean'])):
#     k=1; e=[[[k,-k,k],[0,0,0]],[[0,0,0],[k,k,k]],
#             [[k,k,k],[-k,k,k]],[[-k,k,k],[-k,-k,k]],
#             [[-k,-k,k],[k,-k,k]],[[k,-k,k],[k,k,k]],
#             [[k,k,k],[k,k,-k]],[[k,k,-k],[-k,k,-k]],
#             [[-k,k,-k],[-k,-k,-k]],[[-k,-k,-k],[k,-k,-k]],
#             [[k,-k,-k],[k,k,-k]],[[k,k,-k],[0,0,0]],
#             [[0,0,0],[k,-k,-k]],[[k,-k,-k],[k,-k,k]]]
#     if projection=='perspective_dof':
#         t=Tachyon(xres=400,yres=400,projection=projection,
#                   camera_center=(-3.5,0.,0.),
#                   antialiasing=3,raydepth=5,
#                   focallength='2.0',aperture='.003')
#     else: t=Tachyon(xres=400,yres=400,projection=projection,
#                     camera_center=(-3.5,0.,0.))
#     for i in [0..13]:
#         t.texture('t%s'%str(i),opacity=.3,
#                   color=colormaps[cmap](.077*i)[:3])
#         t.fcylinder(e[i][0],e[i][1],.06,'t%s'%str(i))
#     t.light((-5,-5,5),.1,(1,1,1)); t.show()
# </script></div>
#   </body>
# </html>

# %%
from IPython.display import HTML
#file3=interactive_polar_plotting.html
html_str="""<html><head><meta charset='utf-8'>"""+\
"""<meta name='viewport' content='width=device-width'>"""+\
"""<script src='https://sagecell.sagemath.org/static/embedded_sagecell.js'>"""+\
"""</script><script>$(function(){ sagecell.makeSagecell({"""+\
"""inputLocation:'#cell1',template:sagecell.templates.minimal,"""+\
"""evalButtonText:'run'}); });</script></head><style>"""+\
"""h3 {color:#aa33ff; text-shadow:4px 4px 4px slategray;} """+\
"""pre {width:99%; padding-left:3px; border:2px double slategray;} """+\
""".sagecell_output {width:99%; border:2px double slategray; padding-right:3px;} """+\
""".sagecell_interactControlLabel:hover {padding-left:3px; color:#aa33ff; font-size:120%;} """+\
""".sagecell_interactOutput {padding-left:3px;}</style><body><h3>"""+\
"""$$\large{\mathbb{Interactive \; Polar \; Plotting}}$$</h3>"""+\
"""<p>Click the $\large{\mathbb{run}}$ button to display an example.</p>"""+\
"""<pre><code>\nc=list(colors.keys()); f(x,t)=sin(5*x)^2+0.02*t"""+\
"""\n@interact"""+\
"""\ndef _(number=[20,28,..,len(c)]):"""+\
"""\n    p=sum([polar_plot(f(x,i),(x,0,2*pi),plot_points=30,"""+\
"""\n                      thickness=1,color=c[i-1]) """+\
"""\n           for i in [1..number]])"""+\
"""\n    p.show(figsize=(5,5),gridlines=True) \n"""+\
"""</code></pre><br/>"""+\
"""<div id='cell1'><script type='text/x-sage'>"""+\
"""\nc=list(colors.keys()); f(x,t)=sin(5*x)^2+0.02*t \n@interact"""+\
"""\ndef _(number=[20,28,..,len(c)]):"""+\
"""\n    p=sum([polar_plot(f(x,i),(x,0,2*pi),plot_points=30,"""+\
"""\n                      thickness=1,color=c[i-1]) """+\
"""\n           for i in [1..number]])"""+\
"""\n    p.show(figsize=(5,5),gridlines=True)"""+\
"""</script></div></body></html>"""
HTML(html_str)
# Out:
# <html><head><meta charset='utf-8'><meta name='viewport' content='width=device-width'><script src='https://sagecell.sagemath.org/static/embedded_sagecell.js'></script><script>$(function(){ sagecell.makeSagecell({inputLocation:'#cell1',template:sagecell.templates.minimal,evalButtonText:'run'}); });</script></head><style>h3 {color:#aa33ff; text-shadow:4px 4px 4px slategray;} pre {width:99%; padding-left:3px; border:2px double slategray;} .sagecell_output {width:99%; border:2px double slategray; padding-right:3px;} .sagecell_interactControlLabel:hover {padding-left:3px; color:#aa33ff; font-size:120%;} .sagecell_interactOutput {padding-left:3px;}</style><body><h3>$$\large{\mathbb{Interactive \; Polar \; Plotting}}$$</h3><p>Click the $\large{\mathbb{run}}$ button to display an example.</p><pre><code>
# c=list(colors.keys()); f(x,t)=sin(5*x)^2+0.02*t
# @interact
# def _(number=[20,28,..,len(c)]):
#     p=sum([polar_plot(f(x,i),(x,0,2*pi),plot_points=30,
#                       thickness=1,color=c[i-1])
#            for i in [1..number]])
#     p.show(figsize=(5,5),gridlines=True)
# </code></pre><br/><div id='cell1'><script type='text/x-sage'>
# c=list(colors.keys()); f(x,t)=sin(5*x)^2+0.02*t
# @interact
# def _(number=[20,28,..,len(c)]):
#     p=sum([polar_plot(f(x,i),(x,0,2*pi),plot_points=30,
#                       thickness=1,color=c[i-1])
#            for i in [1..number]])
#     p.show(figsize=(5,5),gridlines=True)</script></div></body></html>

# %%
dhtml('Python Files Embedding','#aa33ff',f2,fs8)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#aa33ff; font-size:30px;'>
#     Python Files Embedding</h1>

# %%
# %run ../input/python-recipes/multidigraph.py
multidigraph_example()

# %%
multidigraph(
    [('1','2'),('2','3'),('3','7'),
    ('4','1'),('5','2'),('6','7')],
     5,'forestgreen')

# %%
# %run ../input/python-recipes/display_dataframe.py
display_dataframe_example();
# Out:
# <style  type="text/css" >
#     #T_6b5005c0_182e_11eb_9c69_0242ac130202 th {
#           color: darkslategray;
#           font-family: times;
#           font-size: 300%;
#           text-shadow: slategray 2px 2px 2px;
#     }#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col0{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #eff4f4;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col1,#T_6b5005c0_182e_11eb_9c69_0242ac130202row7_col1,#T_6b5005c0_182e_11eb_9c69_0242ac130202row7_col2{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #4f4f6e;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col2,#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col4,#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col1,#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col3,#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col0,#T_6b5005c0_182e_11eb_9c69_0242ac130202row7_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #1a1a25;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row0_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #7e8f9e;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col0{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #94adb4;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col1{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #cbdede;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col2{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #0d0d12;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #9dbabd;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col4{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #a4c2c3;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row1_col5,#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col0,#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col4,#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col1,#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col2,#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col0{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #6b748b;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col1{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #a0bec0;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col2{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #303043;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #1c1c27;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col4{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #798799;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row2_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #585b78;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col2,#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #3c3c54;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col4,#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col2{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #4d4d6b;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row3_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #1d1d28;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col0{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #8497a4;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col1{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #666d85;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col2{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #3a3a50;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #313144;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row4_col5{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #748194;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col0,#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col3{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #ecf3f3;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row5_col4{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #2c2c3d;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col1{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #d3e3e3;
#             color:  #000000;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col4{
#             font-size:  130%;
#             font-family:  times;
#             text-shadow:  slategray 2px 2px 2px;
#             background-color:  #0a0a0f;
#             color:  #f1f1f1;
#         }#T_6b5005c0_182e_11eb_9c69_0242ac130202row6_col5{
#             font-size:  130%;

# %%
# %run ../input/python-recipes/amplitude_wavfile.py
